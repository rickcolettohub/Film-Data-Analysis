# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ### Download from Kaggle

# %% [markdown]
# OBS: Para fazer o download do dataset é necessario ter a apikey salva na pasta: <br />
# ```
# Linux/Mac: ~/.kaggle/kaggle.json
# Windows: C:\Users\user\.kaggle\kaggle.json
# ```

# %%
import os
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi

# Api kaggle
api = KaggleApi()
api.authenticate()

# Raw data Directory
RAW_DATA_DIR = "../data/raw"
os.makedirs(RAW_DATA_DIR, exist_ok=True)
# data set path
DATASET = "ggtejas/tmdb-imdb-merged-movies-dataset"

# download and unzip data
try:
    api.dataset_download_files(DATASET, path=RAW_DATA_DIR, unzip=True)
    print(f"Download Finished! Data saved on: {RAW_DATA_DIR}")
except Exception as e:
    print(f"Donload Error: {e}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ggtejas/tmdb-imdb-merged-movies-dataset
# Download Finished! Data saved on: ../data/raw

# %%
df_movies = pd.read_csv("../data/raw/TMDB  IMDB Movies Dataset.csv")
df_movies.sample(10)
# Out:
#             id                 title  vote_average  vote_count    status  \
# 415735  771440        Fall Back Down          0.00           0  Released
# 268261   67874                  Corn          4.00           1  Released
# 358214   38193               Perkele          0.00           0  Released
# 178900   83317      Busty Lifeguards          6.50           2  Released
# 198373  184852  Silence of the Grave          3.00           2  Released
# 426841  832482            Play Money          0.00           0  Released
# 435559  813812             Himmatvar          0.00           0  Released
# 17080    61940           Some Say No          5.75         110  Released
# 255453  104161             Pinay Pie          1.00           1  Released
# 330669  668356           Death Force          0.00           0  Released
#
#        release_date  revenue  runtime  adult  \
# 415735   2019-12-05        0      104  False
# 268261   2004-10-26        0       97  False
# 358214   2004-12-01        0       20  False
# 178900   2010-07-22        0      170   True
# 198373   1976-12-20        0       83  False
# 426841   2017-01-31        0       87  False
# 435559   1996-06-14        0        0  False
# 17080    2011-01-01        0       95  False
# 255453   2003-09-03        0      115  False
# 330669   1989-11-30        0       79  False
#
#                            backdrop_path  ...                   genres  \
# 415735                               NaN  ...          Comedy, Romance
# 268261                               NaN  ...                      NaN
# 358214                               NaN  ...                      NaN
# 178900                               NaN  ...                      NaN
# 198373  /aBuHfO2iFR8giPG7utTDgpXdQ2g.jpg  ...  Thriller, Crime, Horror
# 426841                               NaN  ...              Documentary
# 435559                               NaN  ...            Action, Drama
# 17080   /vP52pClAcBmXqyymyjaOLbGQCjk.jpg  ...                   Comedy
# 255453                               NaN  ...                   Comedy
# 330669                               NaN  ...         Action, Thriller
#
#                           production_companies      production_countries  \
# 415735                                     NaN                       NaN
# 268261                                     NaN                       NaN
# 358214                                     NaN                       NaN
# 178900                           Elegant Angel  United States of America
# 198373                           Manacoa Films                     Spain
# 426841                          Nameless Films  United States of America
# 435559                                     NaN                       NaN
# 17080                                 Cattleya                     Italy
# 255453  Star Cinema – ABS-CBN Film Productions               Philippines
# 330669                                     NaN                       NaN
#
#         spoken_languages                          keywords  \
# 415735               NaN                               NaN
# 268261           English                               NaN
# 358214               NaN                               NaN
# 178900           English                      erotic movie
# 198373           Spanish  island, killer, child kidnapping
# 426841           English                        video game
# 435559               NaN                               NaN
# 17080            Italian                               NaN
# 255453  Tagalog, English                       philippines
# 330669               NaN                               NaN
#
#                     directors                                        writers  \
# 415735           S.B. Edwards  S.B. Edwards, Michelle Diamond, Ruth Atkinson
# 268261            Dave Silver                                    Dave Silver
# 358214          Arto Tuohimaa       Sampsa Huttunen, Anu Lyra, Arto Tuohimaa
# 178900                  Mason                                            NaN
# 198373           Jesús Franco                   Jesús Franco, Enrique Jarber
# 426841   Anthony Alex Gilmore        Joseph F. Edwards, Anthony Alex Gilmore
# 435559             Talat Jani                                    Miraq Mirza
# 17080   Giambattista Avellino         Fabio Bonifacci, Giambattista Avellino
# 255453      Jose Javier Reyes                              Jose Javier Reyes
# 330669              Frans Nel                                     Emil Kolbe
#
#        averageRating numVotes  \
# 415735           7.3       26
# 268261           4.1      318
# 358214           7.5       76
# 178900           6.4       18
# 198373           5.1      170
# 426841           7.6       20
# 435559           6.3       28
# 17080            6.1      459
# 255453           6.2       51
# 330669           5.1       17
#
#                                                      cast
# 415735  Kira Clavell, Andrew Dunbar, Paula Shaw, Omari...
# 268261  Jena Malone, Don Harvey, Pamela Gray, Peter Mc...
# 358214                  Pertti Koivula, Taisto Reimaluoto
# 178900  Charley Chase, Jayden Jaymes, Phoenix Marie, S...
# 198373  Alberto Dalbés, Glenda Allen, Mario Álex, Mont...
# 426841     Brock Pierce, Marcus Eikenberry, Jared Psigoda
# 435559  Dharmendra, Gajendra Chouhan, Dinesh Hingoo, M...
# 17080   Luca Argentero, Paola Cortellesi, Paolo Ruffin...
# 255453  Joyce Jimenez, Assunta de Rossi, Ai-Ai delas A...
# 330669  John Barrett, Robin Smith, Graham Clarke, Eliz...
#
# [10 rows x 29 columns]

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435632 entries, 0 to 435631
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    435632 non-null  int64
#  1   title                 435632 non-null  object
#  2   vote_average          435632 non-null  float64
#  3   vote_count            435632 non-null  int64
#  4   status                435632 non-null  object
#  5   release_date          415986 non-null  object
#  6   revenue               435632 non-null  int64
#  7   runtime               435632 non-null  int64
#  8   adult                 435632 non-null  bool
#  9   backdrop_path         184660 non-null  object
#  10  budget                435632 non-null  int64
#  11  homepage              54450 non-null   object
#  12  tconst                435632 non-null  object
#  13  original_language     435632 non-null  object
#  14  original_title        435632 non-null  object
#  15  overview              393396 non-null  object
#  16  popularity            435632 non-null  float64
#  17  poster_path           360170 non-null  object
#  18  tagline               91617 non-null   object
#  19  genres                356804 non-null  object
#  20  production_companies  262669 non-null  object
#  21  production_countries  321878 non-null  object
#  22  spoken_languages      332408 non-null  object
#  23  keywords              170944 non-null  object
#  24  directors             425414 non-null  object
#  25  writers               369464 non-null  object
#  26  averageRating         435632 non-null  float64
#  27  numVotes              435632 non-null  int64
#  28  cast                  366749 non-null  object
# dtypes: bool(1), float64(3), int64(6), object(19)
# memory usage: 93.5+ MB
