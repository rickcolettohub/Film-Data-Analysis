# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ### Download from Kaggle

# %% [markdown]
# OBS: Para fazer o download do dataset é necessario ter a apikey salva na pasta: <br />
# ```
# Linux/Mac: ~/.kaggle/kaggle.json
# Windows: C:\Users\user\.kaggle\kaggle.json
# ```

# %%
import os
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi

# Api kaggle
api = KaggleApi()
api.authenticate()

# Raw data Directory
RAW_DATA_DIR = "../data/raw"
os.makedirs(RAW_DATA_DIR, exist_ok=True)
# data set path
DATASET = "ggtejas/tmdb-imdb-merged-movies-dataset"

# download and unzip data
try:
    api.dataset_download_files(DATASET, path=RAW_DATA_DIR, unzip=True)
    print(f"Download Finished! Data saved on: {RAW_DATA_DIR}")
except Exception as e:
    print(f"Donload Error: {e}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ggtejas/tmdb-imdb-merged-movies-dataset
# Download Finished! Data saved on: ../data/raw

# %%
df_movies = pd.read_csv("../data/raw/TMDB  IMDB Movies Dataset.csv")
df_movies.sample(10)
# Out:
#              id                                              title  \
# 92861    165220                                     The Mind's Eye
# 22422     29371  The Incredibly True Adventure of Two Girls in ...
# 386760   394512                                 Reise in die Nacht
# 404150  1018833                                           Kingston
# 244858   412423                                      War and Games
# 44643   1059241                           Ghosts and the Afterlife
# 129360   638442                                          Deep Love
# 225239   802885                                        Tutto torna
# 153163   291478                                 El hijo del diablo
# 268404   418469                            forty years without sex
#
#         vote_average  vote_count    status release_date  revenue  runtime  \
# 92861          7.000           7  Released   1990-02-07        0       39
# 22422          6.204          71  Released   1995-06-16        0       94
# 386760         0.000           0  Released   1998-08-28        0        0
# 404150         0.000           0  Released   1976-09-15        0      100
# 244858         8.000           1  Released   2016-08-18        0       95
# 44643          9.565          23  Released   2022-10-15        0       90
# 129360         6.500           4  Released   2019-02-08        0       14
# 225239         6.000           1  Released   2008-05-09        0        0
# 153163         5.000           3  Released   1966-09-09        0       88
# 268404         4.000           1  Released   1979-02-12        0        0
#
#         adult                     backdrop_path  ...                  genres  \
# 92861   False  /ms4y2vhF3uNLB3sWMvQ6NsAkFBf.jpg  ...               Animation
# 22422   False  /l6UDyPqHXxRECt8NyrBYJkdBptu.jpg  ...  Comedy, Drama, Romance
# 386760  False                               NaN  ...                   Drama
# 404150  False                               NaN  ...         Drama, TV Movie
# 244858  False                               NaN  ...             Documentary
# 44643   False                               NaN  ...             Documentary
# 129360  False                               NaN  ...       Animation, Comedy
# 225239  False  /9C1TmPiqqmKldssHd7xDSiVKBRG.jpg  ...                  Comedy
# 153163  False                               NaN  ...                     NaN
# 268404  False                               NaN  ...                  Comedy
#
#                                      production_companies  \
# 92861                                 Miramar Images Inc.
# 22422                                      Smash Pictures
# 386760                                                NaN
# 404150  Groverton Productions, R.B. Productions, Unive...
# 244858  Deutscher Filmförderfonds, Bildersturm Filmpro...
# 44643                           Hollywood Picture Studios
# 129360                        Ukrainian State Film Agency
# 225239                                        Zaroff Film
# 153163                                                NaN
# 268404                Productions 2000, Producciones Zeta
#
#             production_countries spoken_languages  \
# 92861   United States of America      No Language
# 22422   United States of America          English
# 386760                   Germany              NaN
# 404150  United States of America          English
# 244858                   Germany  English, German
# 44643   United States of America              NaN
# 129360                   Ukraine      No Language
# 225239                     Italy          Italian
# 153163                       NaN          Spanish
# 268404            Belgium, Spain          Spanish
#
#                                                  keywords  \
# 92861           computer, music video, computer animation
# 22422   coming out, birthday, gas station, gay interes...
# 386760                                                NaN
# 404150                                                NaN
# 244858                                     woman director
# 44643                                                 NaN
# 129360                                                NaN
# 225239                                                NaN
# 153163                                                NaN
# 268404                                                NaN
#
#                      directors  \
# 92861              Jan Nickman
# 22422           Maria Maggenti
# 386760       Matti Geschonneck
# 404150              Robert Day
# 244858         Karin Jurschick
# 44643              Steve Sayre
# 129360           Mykyta Lyskov
# 225239        Enrico Pitzianti
# 153163  Zacarías Gómez Urquiza
# 268404              Juan Bosch
#
#                                                   writers averageRating  \
# 92861                                                 NaN           7.6
# 22422                                      Maria Maggenti           6.6
# 386760                     Susan Cuscuna, Wolfgang Tumler           6.5
# 404150                          Dick Nelson, David Victor           6.3
# 244858                                    Karin Jurschick           6.9
# 44643                                         Steve Sayre           6.1
# 129360                                      Mykyta Lyskov           7.2
# 225239  Enrico Pitzianti, Paolo Maccioni, Antonia Iacc...           6.9
# 153163        Zacarías Gómez Urquiza, Felipe Mier Miranda           5.6
# 268404  Francesc Bellmunt, Ramon Barnils, Juan Bosch, ...           4.3
#
#        numVotes                                               cast
# 92861       302                                                NaN
# 22422      5649  Laurel Holloman, Nicole Ari Parker, Maggie Moo...
# 386760       20  Ulrike Kriener, Julia Brendler, Renan Demirkan...
# 404150       11  Raymond Burr, James Canning, Pamela Hensley, L...
# 244858        8                                                NaN
# 44643       923  Kelsey Bohlen, Raymond Moody, Norm Shealy, Jay...
# 129360      102                                                NaN
# 225239       17  Antonio Careddu, Piero Marcialis, Yonaiki Broc...
# 153163       18  Joaquín Cordero, Jorge Russek, Alma Delia Fuen...
# 268404       43  Marta Angelat, José Antonio Ceinos, Alfred Luc...
#
# [10 rows x 29 columns]

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435632 entries, 0 to 435631
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    435632 non-null  int64
#  1   title                 435632 non-null  object
#  2   vote_average          435632 non-null  float64
#  3   vote_count            435632 non-null  int64
#  4   status                435632 non-null  object
#  5   release_date          415986 non-null  object
#  6   revenue               435632 non-null  int64
#  7   runtime               435632 non-null  int64
#  8   adult                 435632 non-null  bool
#  9   backdrop_path         184660 non-null  object
#  10  budget                435632 non-null  int64
#  11  homepage              54450 non-null   object
#  12  tconst                435632 non-null  object
#  13  original_language     435632 non-null  object
#  14  original_title        435632 non-null  object
#  15  overview              393396 non-null  object
#  16  popularity            435632 non-null  float64
#  17  poster_path           360170 non-null  object
#  18  tagline               91617 non-null   object
#  19  genres                356804 non-null  object
#  20  production_companies  262669 non-null  object
#  21  production_countries  321878 non-null  object
#  22  spoken_languages      332408 non-null  object
#  23  keywords              170944 non-null  object
#  24  directors             425414 non-null  object
#  25  writers               369464 non-null  object
#  26  averageRating         435632 non-null  float64
#  27  numVotes              435632 non-null  int64
#  28  cast                  366749 non-null  object
# dtypes: bool(1), float64(3), int64(6), object(19)
# memory usage: 93.5+ MB
