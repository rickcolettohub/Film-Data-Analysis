# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ### Download from Kaggle

# %% [markdown]
# OBS: Para fazer o download do dataset é necessario ter a apikey salva na pasta: <br />
# ```
# Linux/Mac: ~/.kaggle/kaggle.json
# Windows: C:\Users\user\.kaggle\kaggle.json
# ```

# %%
import os
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi

# Api kaggle
api = KaggleApi()
api.authenticate()

# Raw data Directory
RAW_DATA_DIR = "../data/raw"
os.makedirs(RAW_DATA_DIR, exist_ok=True)
# data set path
DATASET = "asaniczka/tmdb-movies-dataset-2023-930k-movies"

# download and unzip data
try:
    api.dataset_download_files(DATASET, path=RAW_DATA_DIR, unzip=True)
    print(f"Download Finished! Data saved on: {RAW_DATA_DIR}")
except Exception as e:
    print(f"Donload Error: {e}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/asaniczka/tmdb-movies-dataset-2023-930k-movies
# Donload Error: time data 'Thu, 16 Oct 2025 08:49:20 GMT' does not match format '%a, %d %b %Y %H:%M:%S %Z'

# %% [markdown]
# - Download realizado manualmente devido ao erro nos metadados do cabeçalho do kaggle

# %%
df_movies = pd.read_csv("../data/raw/TMDB_movie_dataset_v11.csv")
df_movies.sample(10)
# Out:
#               id                                              title  \
# 524748   1154867                                We Want to be Heard
# 1289018   791059                                  The Greatest Bond
# 788971   1365361  So I Ordered 72 Pizzas to his house and this w...
# 700822   1327474                            The Tuskar Rock Tragedy
# 923862    590645                             P.A Méthot - P.Arty 80
# 614174   1445672                           Our One and Only Bab(o)y
# 839012    583025                                              hojes
# 909549    666772                                      Nine Coo Five
# 310864   1061204                        Sarasin Bridge of Love 2216
# 520781   1205806                                  Allergic Reaction
#
#          vote_average  vote_count    status release_date  revenue  runtime  \
# 524748            0.0           0  Released   2006-01-01        0        1
# 1289018           0.0           0  Released   2020-05-22        0       54
# 788971            0.0           0  Released   2018-11-05     1000       21
# 700822            0.0           0  Released          NaN        0        0
# 923862            0.0           0  Released   2015-12-19        0        0
# 614174            0.0           0  Released          NaN        0       20
# 839012            0.0           0  Released   2018-12-31        0        0
# 909549            0.0           0  Released   2019-11-16        0        3
# 310864            4.0           1  Released   2023-01-19        0      115
# 520781            0.0           0  Released   2022-04-12        0        3
#
#          adult                     backdrop_path  ...  \
# 524748   False                               NaN  ...
# 1289018  False                               NaN  ...
# 788971   False                               NaN  ...
# 700822   False                               NaN  ...
# 923862   False                               NaN  ...
# 614174   False                               NaN  ...
# 839012   False                               NaN  ...
# 909549   False                               NaN  ...
# 310864   False  /78qQhaPwyyySnSd7FSZppkABFVI.jpg  ...
# 520781   False                               NaN  ...
#
#                                             original_title  \
# 524748                              Queremos que nos oigan
# 1289018                                  The Greatest Bond
# 788971   So I Ordered 72 Pizzas to his house and this w...
# 700822                             The Tuskar Rock Tragedy
# 923862                              P.A Méthot - P.Arty 80
# 614174                            Our One and Only Bab(o)y
# 839012                                               hojes
# 909549                                       Nine Coo Five
# 310864                                 สะพานรักสารสิน 2216
# 520781                                   Allergic Reaction
#
#                                                   overview popularity  \
# 524748   A group of kids start their own band after bei...      0.600
# 1289018  An inspirational and heartwarming one-hour doc...      0.600
# 788971   Hi welcome to a video, it makes no sense just ...      0.658
# 700822                                                 NaN      0.000
# 923862                                                 NaN      0.854
# 614174   Badi, suffering from lung cancer, and Thelma h...      0.600
# 839012                                                 NaN      0.600
# 909549   In a gloomy city square, a talented artist str...      0.600
# 310864   Love story between a young man hired to tap ru...      0.600
# 520781   Two specially trained agents must use their sk...      0.000
#
#                               poster_path  \
# 524748   /1YuKadwWah1Mup5fIbIqL01JEuM.jpg
# 1289018  /cS9wuYJwegLhTftaKchzm1a954J.jpg
# 788971   /nUYEkCZK3sxQpe0gZUZ15lKH8Cg.jpg
# 700822                                NaN
# 923862   /3hykILGfVZVUryMvp81cwA8wpoF.jpg
# 614174   /yKJ2wvFcc6Sw1Vqoq9jfGIpKdGM.jpg
# 839012   /AeVcsbxSAxnRwsiULAUps8GZMcv.jpg
# 909549   /5rhJ7GAjqo7wOj5tQJC5xKvgpwT.jpg
# 310864   /vIeYZiMqlIfdC221FxiYQUw9Md8.jpg
# 520781                                NaN
#
#                                                    tagline            genres  \
# 524748                                                 NaN  Music, Animation
# 1289018  An inspiring film about veterans transformed t...       Documentary
# 788971                                       THIN CRUST!!!            Comedy
# 700822                                                 NaN               NaN
# 923862                                                 NaN            Family
# 614174                                                 NaN               NaN
# 839012                                                 NaN          Thriller
# 909549                                                 NaN         Animation
# 310864                                                 NaN    Drama, Romance
# 520781                                    Watch your step.            Action
#
#                            production_companies      production_countries  \
# 524748                                      NaN                   Uruguay
# 1289018                                     NaN                       NaN
# 788971                           SkeppyShop.com  United States of America
# 700822                                      NaN                       NaN
# 923862                                      NaN                    Canada
# 614174                                      NaN                       NaN
# 839012                                      NaN                    Brazil
# 909549                                      NaN            United Kingdom
# 310864   Mae Riang Film, Pai Roi Kor Production                  Thailand
# 520781                                      NaN                       NaN
#
#         spoken_languages                             keywords
# 524748           Spanish                                  NaN
# 1289018              NaN                                  NaN
# 788971               NaN  pizza, troll, minecraft, thin crust
# 700822               NaN                                  NaN
# 923862            French                                  NaN
# 614174               NaN                                  NaN
# 839012               NaN                                  NaN
# 909549               NaN                                  NaN
# 310864              Thai                                  NaN
# 520781               NaN                                  NaN
#
# [10 rows x 24 columns]

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435632 entries, 0 to 435631
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    435632 non-null  int64
#  1   title                 435632 non-null  object
#  2   vote_average          435632 non-null  float64
#  3   vote_count            435632 non-null  int64
#  4   status                435632 non-null  object
#  5   release_date          415986 non-null  object
#  6   revenue               435632 non-null  int64
#  7   runtime               435632 non-null  int64
#  8   adult                 435632 non-null  bool
#  9   backdrop_path         184660 non-null  object
#  10  budget                435632 non-null  int64
#  11  homepage              54450 non-null   object
#  12  tconst                435632 non-null  object
#  13  original_language     435632 non-null  object
#  14  original_title        435632 non-null  object
#  15  overview              393396 non-null  object
#  16  popularity            435632 non-null  float64
#  17  poster_path           360170 non-null  object
#  18  tagline               91617 non-null   object
#  19  genres                356804 non-null  object
#  20  production_companies  262669 non-null  object
#  21  production_countries  321878 non-null  object
#  22  spoken_languages      332408 non-null  object
#  23  keywords              170944 non-null  object
#  24  directors             425414 non-null  object
#  25  writers               369464 non-null  object
#  26  averageRating         435632 non-null  float64
#  27  numVotes              435632 non-null  int64
#  28  cast                  366749 non-null  object
# dtypes: bool(1), float64(3), int64(6), object(19)
# memory usage: 93.5+ MB
