# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ### Download from Kaggle

# %% [markdown]
# OBS: Para fazer o download do dataset é necessario ter a apikey salva na pasta: <br />
# ```
# Linux/Mac: ~/.kaggle/kaggle.json
# Windows: C:\Users\user\.kaggle\kaggle.json
# ```

# %%
import os
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi

# Api kaggle
api = KaggleApi()
api.authenticate()

# Raw data Directory
RAW_DATA_DIR = "../data/raw"
os.makedirs(RAW_DATA_DIR, exist_ok=True)
# data set path
DATASET = "rounakbanik/the-movies-dataset"

# download and unzip data
try:
    api.dataset_download_files(DATASET, path=RAW_DATA_DIR, unzip=True)
    print(f"Download Finished! Data saved on: {RAW_DATA_DIR}")
except Exception as e:
    print(f"Donload Error: {e}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset
# Download Finished! Data saved on: ../data/raw

# %%
df_movies = pd.read_csv("../data/raw/movies_metadata.csv")
df_movies.sample(10)
# Out:
# C:\Users\Rick\AppData\Local\Temp\ipykernel_5352\1689543279.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies = pd.read_csv("../data/raw/movies_metadata.csv")
#        adult                              belongs_to_collection   budget  \
# 16281  False  {'id': 256297, 'name': "It's Alive Collection"...        0
# 35284  False                                                NaN  1000000
# 38130  False                                                NaN        0
# 13263  False                                                NaN        0
# 35376  False                                                NaN        0
# 21613  False                                                NaN        0
# 37622  False                                                NaN        0
# 27662  False                                                NaN        0
# 32699  False                                                NaN        0
# 8853   False                                                NaN        0
#
#                                                   genres  \
# 16281                     [{'id': 27, 'name': 'Horror'}]
# 35284  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 38130  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 13263  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 35376  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 21613                      [{'id': 18, 'name': 'Drama'}]
# 37622  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 27662  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 32699                                                 []
# 8853   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                                                 homepage      id    imdb_id  \
# 16281                                                NaN   49684  tt0093286
# 35284               http://www.anotherworldthemovie.com/  120172  tt1920846
# 38130                                                NaN  332283  tt3906082
# 13263                                                NaN    8927  tt1232826
# 35376                                                NaN  363476  tt5156770
# 21613  http://www.montereymedia.com/theatrical/films/...  158895  tt1798291
# 37622                                                NaN  332704  tt2784936
# 27662                                                NaN  123235  tt1885331
# 32699                                                NaN  198204  tt0020425
# 8853                                                 NaN  108241  tt0087789
#
#       original_language                       original_title  \
# 16281                en  It's Alive III: Island of the Alive
# 35284                he                        Another World
# 38130                en                         Mary Shelley
# 13263                sv                       De ofrivilliga
# 35376                fr                   Charming Christmas
# 21613                en                This Is Martin Bonner
# 37622                en                            Backtrack
# 27662                fr                      Paris-Manhattan
# 32699                en                   So This Is College
# 8853                 en                          Next of Kin
#
#                                                 overview  ... release_date  \
# 16281  The mutant babies have been placed by court or...  ...   1987-01-01
# 35284  The movie is a post-apocalyptic horror/science...  ...   2014-09-14
# 38130  The love affair between poet Percy Shelley and...  ...   2018-04-25
# 13263  It's almost summer in Sweden and minor indiscr...  ...   2008-11-28
# 35376  Meredith Rossman is the uptight heiress of Ros...  ...   2015-11-08
# 21613  Two men, at opposite ends of the social spectr...  ...   2013-06-28
# 37622  Troubled psychotherapist Peter Bowers is suffe...  ...   2015-07-25
# 27662  In Paris, the pharmacist Alice has been an obs...  ...   2012-07-16
# 32699  Biff and Eddie are the best of friends. They a...  ...   1929-11-08
# 8853   Twenty-three-year old Peter Foster is an only ...  ...   1984-11-30
#
#       revenue runtime                                   spoken_languages  \
# 16281     0.0    95.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 35284     0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 38130     0.0     0.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13263     0.0    98.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 35376     0.0    84.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 21613     0.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 37622     0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 27662     0.0    79.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 32699     0.0    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 8853      0.0    70.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#                 status                                            tagline  \
# 16281         Released  They do something worse than kill. They multiply.
# 35284         Released                                                NaN
# 38130  Post Production                                                NaN
# 13263         Released                                                NaN
# 35376         Released                                                NaN
# 21613         Released  Sometimes You Have to Lose Your Life in Order ...
# 37622         Released                       Nothing haunts like the past
# 27662         Released                 Two cities. One hopeless romantic.
# 32699         Released                                                NaN
# 8853          Released                                                NaN
#
#                                      title  video vote_average vote_count
# 16281  It's Alive III: Island of the Alive  False          4.6       12.0
# 35284                        Another World  False          3.9       28.0
# 38130                         Mary Shelley  False          0.0        1.0
# 13263                          Involuntary  False          6.9       19.0
# 35376                   Charming Christmas  False          5.9       10.0
# 21613                This Is Martin Bonner  False          6.6        4.0
# 37622                            Backtrack  False          5.7      131.0
# 27662                      Paris-Manhattan  False          5.3       67.0
# 32699                   So This Is College  False          0.0        0.0
# 8853                           Next of Kin  False          5.1        6.0
#
# [10 rows x 24 columns]

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435632 entries, 0 to 435631
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    435632 non-null  int64
#  1   title                 435632 non-null  object
#  2   vote_average          435632 non-null  float64
#  3   vote_count            435632 non-null  int64
#  4   status                435632 non-null  object
#  5   release_date          415986 non-null  object
#  6   revenue               435632 non-null  int64
#  7   runtime               435632 non-null  int64
#  8   adult                 435632 non-null  bool
#  9   backdrop_path         184660 non-null  object
#  10  budget                435632 non-null  int64
#  11  homepage              54450 non-null   object
#  12  tconst                435632 non-null  object
#  13  original_language     435632 non-null  object
#  14  original_title        435632 non-null  object
#  15  overview              393396 non-null  object
#  16  popularity            435632 non-null  float64
#  17  poster_path           360170 non-null  object
#  18  tagline               91617 non-null   object
#  19  genres                356804 non-null  object
#  20  production_companies  262669 non-null  object
#  21  production_countries  321878 non-null  object
#  22  spoken_languages      332408 non-null  object
#  23  keywords              170944 non-null  object
#  24  directors             425414 non-null  object
#  25  writers               369464 non-null  object
#  26  averageRating         435632 non-null  float64
#  27  numVotes              435632 non-null  int64
#  28  cast                  366749 non-null  object
# dtypes: bool(1), float64(3), int64(6), object(19)
# memory usage: 93.5+ MB
